# %%
# 导入依赖库
import pandas as pd
import torch
from torch import nn
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from torch.utils.data import TensorDataset, DataLoader
from sklearn.metrics import mean_squared_error
# %matplotlib inline
plt.rcParams['font.sans-serif'] = ['SimHei']  # 中文显示
plt.rcParams['axes.unicode_minus'] = False

# %%
# 加载健康指标数据
def load_hi_from_csv(train_file_path="train_HI.csv", test_file_path="test_HI.csv"):
    train_df = pd.read_csv(train_file_path)
    test_df = pd.read_csv(test_file_path)
    print(f"Training HI loaded from {train_file_path}")
    print(f"Testing HI loaded from {test_file_path}")
    return train_df, test_df

# %%
# 加载数据
train_df, test_df = load_hi_from_csv()
RUL_df = pd.read_csv(r"data\RUL_FD001.txt", header=None)
# Out:
# Training HI loaded from train_HI.csv
# Testing HI loaded from test_HI.csv

# %%
# 数据准备
seq_length = 31

def prepare_sequences(df, seq_length=31, is_train=True):
    X, y = [], []
    engines = df['unit'].unique()
    for eng in engines:
        eng_data = df[df['unit'] == eng]
        hi = eng_data['HI_smooth'].values
        if is_train:
            rul = eng_data['time'].max() - eng_data['time']
            for i in range(len(hi) - seq_length):
                X.append(hi[i:i+seq_length])
                y.append(rul.iloc[i+seq_length])
        else:
            if len(hi) >= seq_length:
                X.append(hi[-seq_length:])
            else:
                padding = np.full((seq_length - len(hi),), hi[0])
                X.append(np.concatenate([padding, hi]))
    return np.array(X), np.array(y) if is_train else np.array(X)

X_train, y_train = prepare_sequences(train_df, seq_length)
X_test, _ = prepare_sequences(test_df, seq_length, is_train=False)
test_rul = RUL_df[0].values

# 数据标准化
scaler_X = MinMaxScaler()
scaler_y = MinMaxScaler()
X_train = scaler_X.fit_transform(X_train.reshape(-1, 1)).reshape(X_train.shape)
X_test = scaler_X.transform(X_test.reshape(-1, 1)).reshape(X_test.shape)
y_train = scaler_y.fit_transform(y_train.reshape(-1, 1)).flatten()

# 划分验证集
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
# 数据加载器
def create_dataloader(X, y=None, batch_size=32, shuffle=False):
    X_tensor = torch.FloatTensor(X).unsqueeze(-1)
    if y is not None:
        y_tensor = torch.FloatTensor(y)
        dataset = TensorDataset(X_tensor, y_tensor)
    else:
        dataset = TensorDataset(X_tensor)
    return DataLoader(dataset, batch_size=batch_size, shuffle=shuffle)

train_loader = create_dataloader(X_train, y_train, batch_size=32, shuffle=True)
val_loader = create_dataloader(X_val, y_val, batch_size=32)
test_loader = create_dataloader(X_test, batch_size=32)

# %%
# 改进的注意力机制
class ImprovedAttention(nn.Module):
    def __init__(self, seq_length):
        super(ImprovedAttention, self).__init__()
        self.seq_length = seq_length

        # Learnable weights for early, middle, and late stages
        self.early_weight = nn.Parameter(torch.ones(1))  # Learnable scalar for early stage
        self.middle_weight = nn.Parameter(torch.ones(1))  # Learnable scalar for middle stage
        self.late_weight = nn.Parameter(torch.ones(1))  # Learnable scalar for late stage

        # Positional encoding to differentiate time steps
        self.positional_encoding = nn.Parameter(torch.linspace(0, seq_length - 1, seq_length))

        # Softmax for normalizing attention weights
        self.softmax = nn.Softmax(dim=1)

    def forward(self, inputs):
        batch_size, seq_length, hidden_dim = inputs.shape
        # Compute weights for each time step
        early_stage = torch.sigmoid(-self.positional_encoding + seq_length / 3)  # Higher for early stage
        middle_stage = torch.exp(-((self.positional_encoding - seq_length / 2) ** 2) / (2 * (seq_length / 6) ** 2))  # Gaussian for middle
        late_stage = torch.sigmoid(self.positional_encoding - 2 * seq_length / 3)  # Higher for late stage
        # Combine stage weights with learnable parameters
        stage_weights = (
            self.early_weight * early_stage
            + self.middle_weight * middle_stage
            + self.late_weight * late_stage
        )
        # Reshape stage_weights to (1, seq_length) for softmax
        stage_weights = stage_weights.unsqueeze(0)  # Shape becomes (1, seq_length)      
        # Normalize the stage weights using softmax
        attention_weights = self.softmax(stage_weights)  # Shape becomes (1, seq_length)      
        # Expand attention_weights to match batch size
        attention_weights = attention_weights.expand(batch_size, -1)  # Shape becomes (batch_size, seq_length)
        # Apply attention weights to the inputs
        weighted_inputs = inputs * attention_weights.unsqueeze(-1)  # Shape remains (batch_size, seq_length, hidden_dim)
        return weighted_inputs, attention_weights

# 模型定义
class ImprovedBiLSTMModel(nn.Module):
    def __init__(self, seq_length, hidden_dim=256, dropout_rate=0.3):
        super(ImprovedBiLSTMModel, self).__init__()
        self.lstm1 = nn.LSTM(input_size=1, hidden_size=hidden_dim, num_layers=1, bidirectional=True, batch_first=True)
        self.lstm2 = nn.LSTM(input_size=hidden_dim*2, hidden_size=hidden_dim, num_layers=1, bidirectional=True, batch_first=True)
        self.attention = ImprovedAttention(seq_length)
        self.fc = nn.Sequential(
            nn.Linear(hidden_dim*2, 128),
            nn.ReLU(),
            nn.Dropout(dropout_rate),
            nn.Linear(128, 1)
        )

    def forward(self, x):
        x, _ = self.lstm1(x)
        x, _ = self.lstm2(x)
        x, attention_weights = self.attention(x)
        x = x.mean(dim=1)
        return self.fc(x), attention_weights

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = ImprovedBiLSTMModel(seq_length).to(device)

# %%
# 损失函数和优化器
class WeightedMSELoss(nn.Module):
    def forward(self, y_pred, y_true):
        weights = 1 / (y_true + 1)
        loss = weights * (y_pred - y_true) ** 2
        return torch.mean(loss)

criterion = WeightedMSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5,min_lr=1e-4)

# %%
# 训练循环
def train_model(model, train_loader, val_loader, criterion, optimizer, scheduler, epochs=50):
    for epoch in range(epochs):
        model.train()
        train_loss = 0
        for batch_X, batch_y in train_loader:
            batch_X, batch_y = batch_X.to(device), batch_y.to(device)
            optimizer.zero_grad()
            outputs, _ = model(batch_X)
            loss = criterion(outputs.squeeze(-1), batch_y)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)
            optimizer.step()
            train_loss += loss.item() * batch_X.size(0)

        # 验证阶段
        model.eval()
        val_loss = 0
        with torch.no_grad():
            for batch_X, batch_y in val_loader:
                batch_X, batch_y = batch_X.to(device), batch_y.to(device)
                outputs, _ = model(batch_X)
                loss = criterion(outputs.squeeze(-1), batch_y)
                val_loss += loss.item() * batch_X.size(0)

        scheduler.step(val_loss)
        print(f"Epoch {epoch+1}/{epochs}, Train Loss: {train_loss/len(train_loader.dataset):.4f}, Val Loss: {val_loss/len(val_loader.dataset):.4f}")

train_model(model, train_loader, val_loader, criterion, optimizer, scheduler, epochs=50)
# Out:
# Epoch 1/50, Train Loss: 0.0260, Val Loss: 0.0250
# Epoch 2/50, Train Loss: 0.0257, Val Loss: 0.0252
# Epoch 3/50, Train Loss: 0.0257, Val Loss: 0.0250
# Epoch 4/50, Train Loss: 0.0258, Val Loss: 0.0251
# Epoch 5/50, Train Loss: 0.0258, Val Loss: 0.0250
# Epoch 6/50, Train Loss: 0.0257, Val Loss: 0.0249
# Epoch 7/50, Train Loss: 0.0258, Val Loss: 0.0250
# Epoch 8/50, Train Loss: 0.0258, Val Loss: 0.0250
# Epoch 9/50, Train Loss: 0.0257, Val Loss: 0.0250
# Epoch 10/50, Train Loss: 0.0258, Val Loss: 0.0252
# Epoch 11/50, Train Loss: 0.0257, Val Loss: 0.0249
# Epoch 12/50, Train Loss: 0.0257, Val Loss: 0.0250
# Epoch 13/50, Train Loss: 0.0257, Val Loss: 0.0249
# Epoch 14/50, Train Loss: 0.0257, Val Loss: 0.0249
# Epoch 15/50, Train Loss: 0.0257, Val Loss: 0.0253
# Epoch 16/50, Train Loss: 0.0257, Val Loss: 0.0249
# Epoch 17/50, Train Loss: 0.0257, Val Loss: 0.0249
# Epoch 18/50, Train Loss: 0.0257, Val Loss: 0.0251
# Epoch 19/50, Train Loss: 0.0257, Val Loss: 0.0249
# Epoch 20/50, Train Loss: 0.0257, Val Loss: 0.0250
# Epoch 21/50, Train Loss: 0.0257, Val Loss: 0.0250
# Epoch 22/50, Train Loss: 0.0257, Val Loss: 0.0251
# Epoch 23/50, Train Loss: 0.0257, Val Loss: 0.0250
# Epoch 24/50, Train Loss: 0.0257, Val Loss: 0.0249
# Epoch 25/50, Train Loss: 0.0256, Val Loss: 0.0250
# Epoch 26/50, Train Loss: 0.0256, Val Loss: 0.0249
# Epoch 27/50, Train Loss: 0.0256, Val Loss: 0.0249
# Epoch 28/50, Train Loss: 0.0256, Val Loss: 0.0249
# Epoch 29/50, Train Loss: 0.0256, Val Loss: 0.0250
# Epoch 30/50, Train Loss: 0.0256, Val Loss: 0.0250
# Epoch 31/50, Train Loss: 0.0256, Val Loss: 0.0249
# Epoch 32/50, Train Loss: 0.0256, Val Loss: 0.0250
# Epoch 33/50, Train Loss: 0.0256, Val Loss: 0.0249
# Epoch 34/50, Train Loss: 0.0256, Val Loss: 0.0250
# Epoch 35/50, Train Loss: 0.0256, Val Loss: 0.0249
# Epoch 36/50, Train Loss: 0.0256, Val Loss: 0.0250
# Epoch 37/50, Train Loss: 0.0256, Val Loss: 0.0249
# Epoch 38/50, Train Loss: 0.0256, Val Loss: 0.0250
# Epoch 39/50, Train Loss: 0.0256, Val Loss: 0.0250
# Epoch 40/50, Train Loss: 0.0256, Val Loss: 0.0250
# Epoch 41/50, Train Loss: 0.0256, Val Loss: 0.0249
# Epoch 42/50, Train Loss: 0.0256, Val Loss: 0.0249
# Epoch 43/50, Train Loss: 0.0256, Val Loss: 0.0249
# Epoch 44/50, Train Loss: 0.0256, Val Loss: 0.0249
# Epoch 45/50, Train Loss: 0.0256, Val Loss: 0.0249
# Epoch 46/50, Train Loss: 0.0256, Val Loss: 0.0249
# Epoch 47/50, Train Loss: 0.0256, Val Loss: 0.0249
# Epoch 48/50, Train Loss: 0.0256, Val Loss: 0.0249
# Epoch 49/50, Train Loss: 0.0256, Val Loss: 0.0249
# Epoch 50/50, Train Loss: 0.0256, Val Loss: 0.0249

# %%
# Predict RUL for the test set and visualize the comparison

# Prediction function for the test set
def predict_test_rul(model, test_loader, scaler_y):
    model.eval()
    all_preds = []

    with torch.no_grad():
        for batch_X, in test_loader:
            batch_X = batch_X.to(device)
            outputs, _ = model(batch_X)
            all_preds.append(outputs.cpu().numpy())

    # Combine all predictions and inverse scale them to original RUL values
    predictions = np.concatenate(all_preds).flatten()
    predictions = scaler_y.inverse_transform(predictions.reshape(-1, 1)).flatten()
    return predictions

# %%
# Generate predictions for the test set
y_pred = predict_test_rul(model, test_loader, scaler_y)

# %%
# Visual comparison between predicted and true RUL
plt.figure(figsize=(12, 6))
plt.plot(test_rul, label='True RUL', marker='o', linestyle='-', color='orange')
plt.plot(y_pred, label='Predicted RUL', marker='x', linestyle='--', color='blue')
plt.title('RUL Prediction Comparison')
plt.xlabel('Engine Unit')
plt.ylabel('Remaining Useful Life')
plt.legend()
plt.grid(True)
plt.show()

# %%
def compute_rmse(y_true, y_pred):
    return np.sqrt(mean_squared_error(y_true, y_pred))

# %%
rmse = compute_rmse(test_rul, y_pred)
# Print RMSE
print(f"Test Set Evaluation Metrics:")
print(f"Root Mean Square Error (RMSE): {rmse:.2f}")
# Out:
# Test Set Evaluation Metrics:
# Root Mean Square Error (RMSE): 42.63
